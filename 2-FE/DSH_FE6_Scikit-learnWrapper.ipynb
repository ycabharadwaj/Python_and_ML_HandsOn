# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from feature_engine.wrappers import SklearnTransformerWrapper

# %%
class feature_engine.wrappers.SklearnTransformerWrapper(variables=None, transformer=None)
# Out:
#   File "<ipython-input-8-afcd9c6908d1>", line 1
#     class feature_engine.wrappers.SklearnTransformerWrapper(variables=None, transformer=None)
#                         ^
# SyntaxError: invalid syntax

# %%
# Load dataset
data = pd.read_csv('houseprice.csv')

# Separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(['Id', 'SalePrice'], axis=1),
    data['SalePrice'], test_size=0.3, random_state=0)

# set up the wrapper with the SimpleImputer
imputer = SklearnTransformerWrapper(transformer = SimpleImputer(strategy='mean'),
                                    variables = ['LotFrontage', 'MasVnrArea'])

# fit the wrapper + SimpleImputer
imputer.fit(X_train)

# transform the data
t_train = imputer.transform(X_train)
t_test = imputer.transform(X_test)

# %%
X_train[X_train['LotFrontage'].isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 64            60       RL          NaN     9375   Pave   NaN      Reg
# 682          120       RL          NaN     2887   Pave   NaN      Reg
# 853           80       RL          NaN    12095   Pave   NaN      IR1
# 328           75       RL          NaN    11888   Pave  Pave      IR1
# 452           60       RL          NaN     9303   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 845           85       RL          NaN    16647   Pave   NaN      IR1
# 537           20       RL          NaN    12735   Pave   NaN      IR1
# 1033          20       RL          NaN     8125   Pave   NaN      Reg
# 1383          30       RL          NaN    25339   Pave   NaN      Reg
# 559          120       RL          NaN     3196   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 64           Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 682          HLS    AllPub    Inside  ...           0        0    NaN    NaN
# 853          Lvl    AllPub    Corner  ...           0        0    NaN  MnPrv
# 328          Bnk    AllPub    Inside  ...           0        0    NaN    NaN
# 452          Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 845          Lvl    AllPub   CulDSac  ...           0        0    NaN    NaN
# 537          Lvl    AllPub       FR2  ...           0        0    NaN   MnWw
# 1033         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1383         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 559          Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 64           NaN       0       2    2009        WD         Normal
# 682          NaN       0      11    2008        WD         Normal
# 853          NaN       0       8    2009        WD         Normal
# 328          NaN       0       7    2009        WD         Normal
# 452          NaN       0       7    2007        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 845          NaN       0       1    2007        WD         Normal
# 537          NaN       0       4    2008       COD         Normal
# 1033         NaN       0       2    2006        WD         Normal
# 1383         NaN       0       8    2007        WD         Normal
# 559          NaN       0      10    2006        WD         Normal
#
# [189 rows x 79 columns]

# %%
t_train.loc[[64,682,559]]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 64           60       RL    69.668667     9375   Pave   NaN      Reg
# 682         120       RL    69.668667     2887   Pave   NaN      Reg
# 559         120       RL    69.668667     3196   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 64          Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 682         HLS    AllPub    Inside  ...           0        0    NaN    NaN
# 559         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#     MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 64          NaN       0       2    2009        WD         Normal
# 682         NaN       0      11    2008        WD         Normal
# 559         NaN       0      10    2006        WD         Normal
#
# [3 rows x 79 columns]

# %%
X_train['LotFrontage'].mean()  # we can see above that LotFrontage NULL is replaced with mean value 69.66
# Out:
# 69.66866746698679
