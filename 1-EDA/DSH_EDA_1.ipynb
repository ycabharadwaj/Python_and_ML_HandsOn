# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('seaborn-data-master/students.csv')

# %%
df.shape  # rows (0 to 56), columns

# here 57 is like select count(*) from table
# Out:
# (57, 26)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=57, step=1)

# %%
df.head()

# select * from table sample top 5
# Out:
#          id first_name last_name date_of_birth               ethnicity gender  \
# 0  111111.0       John       Doe       01/2000                Hispanic      M
# 1  111112.0       Jane     Smith       05/2001                Hispanic      F
# 2  111113.0      Sarah    Thomas       21/2002                Hispanic      M
# 3  111114.0      Frank     Brown       13/2002  Race/ethnicity unknown      M
# 4  111115.0       Mike     Davis       31/2001                   White      F
#
#      status entry_academic_period  exclusion_type  act_composite  ...  \
# 0        FT             Fall 2008             NaN            NaN  ...
# 1  TRANSFER             Fall 2006             NaN            NaN  ...
# 2      FTFT             Fall 2006             NaN           14.0  ...
# 3      FTFT             Fall 2006             NaN            NaN  ...
# 4      FTFT             Fall 2007             NaN           22.0  ...
#
# ...

# %%
df.tail()

# select * from table sample bottom 5
# Out:
#     id first_name last_name date_of_birth ethnicity gender status  \
# 52 NaN        NaN       NaN           NaN       NaN    NaN    NaN
# 53 NaN        NaN       NaN           NaN       NaN    NaN    NaN
# 54 NaN        NaN       NaN           NaN       NaN    NaN    NaN
# 55 NaN        NaN       NaN           NaN       NaN    NaN    NaN
# 56 NaN        NaN       NaN           NaN       NaN    NaN    NaN
#
#    entry_academic_period  exclusion_type  act_composite  ...  sat_reading  \
# 52                   NaN             NaN            NaN  ...          NaN
# 53                   NaN             NaN            NaN  ...          NaN
# 54                   NaN             NaN            NaN  ...          NaN
# 55                   NaN             NaN            NaN  ...          NaN
# 56                   NaN             NaN            NaN  ...          NaN
#
#    hs_gpa  hs_city  hs_state  hs_zip  email  entry_age  ged  \
# ...

# %%
df.describe()
# Out:
#                   id  exclusion_type  act_composite   act_math  act_reading  \
# count       9.000000             0.0       5.000000   5.000000     5.000000
# mean   111115.000000             NaN      19.400000   7.400000     6.000000
# std         2.738613             NaN       4.722288   3.435113     2.645751
# min    111111.000000             NaN      14.000000   4.000000     3.000000
# 25%    111113.000000             NaN      15.000000   5.000000     5.000000
# 50%    111115.000000             NaN      21.000000   6.000000     5.000000
# 75%    111117.000000             NaN      22.000000  10.000000     7.000000
# max    111119.000000             NaN      25.000000  12.000000    10.000000
#
#        sat_combined   sat_math  sat_verbal  sat_reading    hs_gpa  \
# count       2.00000    2.00000    2.000000     2.000000  8.000000
# mean     1085.00000  315.00000  455.000000   215.000000  3.280000
# std       516.18795  289.91378   77.781746     7.071068  0.609473
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     9 non-null      float64
#  1   first_name             9 non-null      object
#  2   last_name              9 non-null      object
#  3   date_of_birth          9 non-null      object
#  4   ethnicity              9 non-null      object
#  5   gender                 9 non-null      object
#  6   status                 9 non-null      object
#  7   entry_academic_period  9 non-null      object
#  8   exclusion_type         0 non-null      float64
#  9   act_composite          5 non-null      float64
#  10  act_math               5 non-null      float64
#  11  act_english            6 non-null      object
#  12  act_reading            5 non-null      float64
#  13  sat_combined           2 non-null      float64
# ...

# %%
 df.columns  # columns list
# Out:
# Index(['id', 'first_name', 'last_name', 'date_of_birth', 'ethnicity', 'gender',
#        'status', 'entry_academic_period', 'exclusion_type', 'act_composite',
#        'act_math', 'act_english', 'act_reading', 'sat_combined', 'sat_math',
#        'sat_verbal', 'sat_reading', 'hs_gpa', 'hs_city', 'hs_state', 'hs_zip',
#        'email', 'entry_age', 'ged', 'english_2nd_language',
#        'first_generation'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                       float64
# first_name                object
# last_name                 object
# date_of_birth             object
# ethnicity                 object
# gender                    object
# status                    object
# entry_academic_period     object
# exclusion_type           float64
# act_composite            float64
# act_math                 float64
# act_english               object
# act_reading              float64
# sat_combined             float64
# sat_math                 float64
# sat_verbal               float64
# sat_reading              float64
# hs_gpa                   float64
# hs_city                   object
# hs_state                  object
# hs_zip                   float64
# email                     object
# entry_age                float64
# ged                       object
# english_2nd_language      object
# first_generation          object
# dtype: object

# %%
df[['id','first_name']].head(5)

# select col1, col2 from table sample 5
# Out:
#          id first_name
# 0  111111.0       John
# 1  111112.0       Jane
# 2  111113.0      Sarah
# 3  111114.0      Frank
# 4  111115.0       Mike

# %%
df.count() 

# Provides row count having data in that column.Eg: 'act_composite' field has data only for 5 rows, so it gives 5.
# Out:
# id                       9
# first_name               9
# last_name                9
# date_of_birth            9
# ethnicity                9
# gender                   9
# status                   9
# entry_academic_period    9
# exclusion_type           0
# act_composite            5
# act_math                 5
# act_english              6
# act_reading              5
# sat_combined             2
# sat_math                 2
# sat_verbal               2
# sat_reading              2
# hs_gpa                   8
# hs_city                  9
# hs_state                 9
# hs_zip                   9
# email                    9
# entry_age                9
# ged                      9
# english_2nd_language     9
# first_generation         9
# dtype: int64

# %%
df['act_composite'].count() # rows with NULL value for that field is not considered in counting.

# select count(*) from table where act_composite is NOT NULL
# Out:
# 5

# %%
df.nunique()  # To check unique values in each column. It doesn't counts NULL. 


#select 
#'id', count(distinct id)
#,'first_name', count(distinct first_name)
#,'last_name', count(distinct last_name) 
#from table
# Out:
# id                       9
# first_name               9
# last_name                9
# date_of_birth            8
# ethnicity                4
# gender                   2
# status                   4
# entry_academic_period    4
# exclusion_type           0
# act_composite            5
# act_math                 5
# act_english              3
# act_reading              4
# sat_combined             2
# sat_math                 2
# sat_verbal               2
# sat_reading              2
# hs_gpa                   8
# hs_city                  6
# hs_state                 6
# hs_zip                   9
# email                    9
# entry_age                8
# ged                      2
# english_2nd_language     2
# first_generation         2
# dtype: int64

# %%
df['hs_state'].unique()  # to check unique value at individual column level. It shows that it has nan(null) value also.


# select column1 from table group by 1  , it doesn't provide null value
# Out:
# array(['New Mexico', 'New York', 'Arizona', 'Washington', 'Colorado',
#        'Texas', nan], dtype=object)

# %%
df['hs_state'].value_counts()   # how many row count for each value in 'hs_state' field. 

# it doesn't consideres the records with NULL value. 


# select column1, count(*) from table group by 1
# Out:
# Colorado      3
# Arizona       2
# New Mexico    1
# New York      1
# Texas         1
# Washington    1
# Name: hs_state, dtype: int64

# %%
# Need to find out how to check unqiue values of 2 columns together like below

# select col1,col2, count(*) from table group by 1,2

# %%
df.isnull().sum()  # To check how many row are NULL at individual column level.

# df.isnull().count()==>doesn't give 48 but it gives 57 i.e including rows with data, not sure why it works like that.


#select 'id', count(*) from table where id is null
#union
#select 'first_name', count(*) from table where first_name is null etc
# Out:
# id                       48
# first_name               48
# last_name                48
# date_of_birth            48
# ethnicity                48
# gender                   48
# status                   48
# entry_academic_period    48
# exclusion_type           57
# act_composite            52
# act_math                 52
# act_english              51
# act_reading              52
# sat_combined             55
# sat_math                 55
# sat_verbal               55
# sat_reading              55
# hs_gpa                   49
# hs_city                  48
# hs_state                 48
# hs_zip                   48
# email                    48
# entry_age                48
# ged                      48
# english_2nd_language     48
# first_generation         48
# dtype: int64

# %%
df['hs_state'].isnull().sum() # To check how many row are NULL for specific column.


#select 'hs_state', count(*) from table where hs_state is null
# Out:
# 48

# %%
df.notnull().sum() # To check how many rows are NOT NULL at individual column level.

#select 'id', count(*) from table where id is not null
#union
#select 'first_name', count(*) from table where first_name is not null etc
# Out:
# id                       9
# first_name               9
# last_name                9
# date_of_birth            9
# ethnicity                9
# gender                   9
# status                   9
# entry_academic_period    9
# exclusion_type           0
# act_composite            5
# act_math                 5
# act_english              6
# act_reading              5
# sat_combined             2
# sat_math                 2
# sat_verbal               2
# sat_reading              2
# hs_gpa                   8
# hs_city                  9
# hs_state                 9
# hs_zip                   9
# email                    9
# entry_age                9
# ged                      9
# english_2nd_language     9
# first_generation         9
# dtype: int64

# %%
 df['hs_state'].notnull().sum() # To check how many rows are NOT NULL at particular column level.
    
#select 'hs_state', count(*) from table where hs_state is not null etc
# Out:
# 9

# %%
df.sort_values(by='first_name')

# select * from table order by first_name asc
# Out:
#           id first_name last_name date_of_birth               ethnicity  \
# 8   111119.0        Bob     Lopez       04/1998                   White
# 3   111114.0      Frank     Brown       13/2002  Race/ethnicity unknown
# 7   111118.0       Fred     Clark       17/1999                Hispanic
# 1   111112.0       Jane     Smith       05/2001                Hispanic
# 5   111116.0   Jennifer    Wilson       01/2002                   Asian
# 6   111117.0    Jessica    Garcia       01/2000                   White
# 0   111111.0       John       Doe       01/2000                Hispanic
# 4   111115.0       Mike     Davis       31/2001                   White
# 2   111113.0      Sarah    Thomas       21/2002                Hispanic
# 9        NaN        NaN       NaN           NaN                     NaN
# 10       NaN        NaN       NaN           NaN                     NaN
# 11       NaN        NaN       NaN           NaN                     NaN
# ...

# %%
df['id'].min()

#select min(id) from table
# Out:
# 111111.0

# %%
df['id'].max()

#select max(id) from table
# Out:
# 111119.0

# %%
df['id'].mean()
# Out:
# 111115.0

# %%
# Relationship Analysis

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('seaborn-data-master/StudentsPerformance.csv')

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
corelation = df1.corr()

# %%
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns)

# %%
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns,annot = True)

# %%
sns.pairplot(df1)

# %%
sns.relplot(x='math score', y = 'reading score', hue = 'gender', data = df1)

# %%
sns.relplot(x='math score', y = 'reading score', hue = 'lunch', data = df1)

# %%
sns.distplot(df['math score'])

# %%
sns.distplot(df['reading score'])

# %%
sns.distplot(df['writing score'])

# %%
sns.catplot(x='math score', kind = 'box', data=df1 )

# %%
df1.shape
# Out:
# (1000, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df1.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df1.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df2 = df1.drop(['race/ethnicity','parental level of education'],axis = 1)

# %%
df2
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...
